# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_train = pd.read_csv("/content/drive/My Drive/DataSets/ds_challenge1/Given_data/train.csv")
df_test = pd.read_csv("/content/drive/My Drive/DataSets/ds_challenge1/Given_data/test.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data1   10000 non-null  int64
#  1   data2   10000 non-null  int64
#  2   data3   10000 non-null  object
#  3   data4   10000 non-null  float64
#  4   data5   9999 non-null   float64
#  5   data6   9997 non-null   float64
#  6   data7   9998 non-null   float64
#  7   data8   9999 non-null   float64
#  8   data9   9999 non-null   object
#  9   data10  9999 non-null   object
#  10  output  9999 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 859.5+ KB

# %%
df_train.dropna(axis = 0, inplace = True)

# %%
# conversion of non numeric features into numeric

# creating label encoder object
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df_train['data3']= label_encoder.fit_transform(df_train['data3']) 
df_train['data9']= label_encoder.fit_transform(df_train['data9'])
df_train['data10']= label_encoder.fit_transform(df_train['data10']) 
   
df_test['data3']= label_encoder.fit_transform(df_test['data3']) 
df_test['data9']= label_encoder.fit_transform(df_test['data9'])
df_test['data10']= label_encoder.fit_transform(df_test['data10'])

# %%
df_train.head()
# Out:
#    data1  data2  data3      data4  ...  data8  data9  data10     output
# 0      8    279      2  14.451155  ...    1.0      1       0  86.108947
# 1      1    108      7  14.207448  ...    0.0      1       0  42.606833
# 2      8    258      0  19.220830  ...    1.0      1       0  85.625961
# 3      4    147      0  15.752732  ...    1.0      1       0  53.656277
# 4      5    230      7  10.195407  ...    0.0      1       0  64.925051
#
# [5 rows x 11 columns]

# %%
df_train.isnull().sum() #Checking for total null values
# Out:
# data1     0
# data2     0
# data3     0
# data4     0
# data5     0
# data6     0
# data7     0
# data8     0
# data9     0
# data10    0
# output    0
# dtype: int64

# %%
np.any(np.isnan(df_train)) #Checking for null values, If True is op then there are null or else Flase
# Out:
# False

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data1'], y = df_train['output'])

# %%
#1 Outlier FOUND, removing it using For loop.
i = df_train.loc[df_train['data1'] > 100].index
print(i)
df_train.drop(i, inplace = True)
# Out:
# Int64Index([18], dtype='int64')

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data1'], y = df_train['output'])

# %%
  from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
_ = df_train['data1'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = df_train['data3'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = df_train['data8'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = df_train['data9'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = df_train['data10'].value_counts().plot(kind='bar')
plt.show()

# %%
_ = df_train['data1'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data2'], y = df_train['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data4'], y = df_train['output'])

# %%
i = df_train.loc[df_train['data4'] > 50].index
print(i)
df_train.drop(i, inplace = True)

i = df_train.loc[df_train['data4'] < 10].index
print(i)
df_train.drop(i, inplace = True)
# Out:
# Int64Index([33], dtype='int64')
# Int64Index([81], dtype='int64')

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data5'], y = df_train['output'])

# %%
i = df_train.loc[df_train['data5'] < 500].index
print(i)
df_train.drop(i, inplace = True)
# Out:
# Int64Index([46], dtype='int64')

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data6'], y = df_train['output'])

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = df_train['data7'], y = df_train['output'])

# %%
del df_train["data10"]
del df_test["data10"]

# %%
df_train
# Out:
#       data1  data2  data3      data4  ...     data7  data8  data9     output
# 0         8    279      2  14.451155  ...  9.302908    1.0      1  86.108947
# 1         1    108      7  14.207448  ...  7.220130    0.0      1  42.606833
# 2         8    258      0  19.220830  ...  8.727214    1.0      1  85.625961
# 3         4    147      0  15.752732  ...  6.078818    1.0      1  53.656277
# 4         5    230      7  10.195407  ...  4.749185    0.0      1  64.925051
# ...     ...    ...    ...        ...  ...       ...    ...    ...        ...
# 9995      9    263      0  16.604215  ...  8.979149    2.0      0  85.922943
# 9996      5    280      4  28.758911  ...  3.574129    0.0      0  90.857149
# 9997      6    188      3  15.963267  ...  2.880019    0.0      0  61.246960
# 9998      1    132      7  11.683401  ...  6.983192    2.0      0  45.298253
# 9999      5    264      0  21.176115  ...  8.276101    2.0      0  85.534604
#
# [9993 rows x 10 columns]

# %%
X = df_train.drop(['output'], axis = 1, inplace = False)
y = df_train['output']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 10)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7494, 9) (2499, 9) (7494,) (2499,)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
df_predict = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_predict
# Out:
#          Actual  Predicted
# 1643  78.109018  78.109018
# 1348  47.901732  47.901732
# 3425  76.584313  76.584313
# 1352  70.346561  70.346561
# 8078  81.167425  81.167425
# ...         ...        ...
# 6890  84.012346  84.012346
# 4290  87.815740  87.815740
# 6079  56.005503  56.005503
# 1496  71.101392  71.101392
# 6998  43.496507  43.496507
#
# [2499 rows x 2 columns]

# %%
r2_score(y_test, y_pred)
# Out:
# 1.0

# %%
df_test
# Out:
#       data1  data2  data3      data4  data5  data6     data7  data8  data9
# 0         7    195      0  29.038043   2725      1  6.145731      2      1
# 1         9    109      5  20.221431   1184      1  9.334184      2      1
# 2         0    126      2  26.477532   2975      1  9.021806      1      1
# 3         2    209      4  13.445450   1067      1  1.814993      0      1
# 4         5    268      1  25.065894   1336      1  1.639130      1      1
# ...     ...    ...    ...        ...    ...    ...       ...    ...    ...
# 9995      7    251      3  23.004384   1637      0  8.333728      1      0
# 9996      5    275      0  29.514058   2339      0  9.953107      1      0
# 9997      8    168      2  22.520965   1827      0  7.555553      1      0
# 9998      4    296      4  16.558948   1748      0  8.846995      1      0
# 9999      7    281      2  18.546089   1651      0  8.907220      2      0
#
# [10000 rows x 9 columns]

# %%
df_test.dropna(axis = 0, inplace = True)

# %%
df_test.isnull().sum()
# Out:
# data1    0
# data2    0
# data3    0
# data4    0
# data5    0
# data6    0
# data7    0
# data8    0
# data9    0
# dtype: int64

# %%
np.any(np.isnan(df_test))
# Out:
# False

# %%
output_Values = regressor.predict(df_test)

# %%
df_inference = pd.DataFrame({'output': output_Values})
df_inference
# Out:
#          output
# 0     78.279970
# 1     58.333472
# 2     58.051585
# 3     57.715898
# 4     82.798435
# ...         ...
# 9995  86.637674
# 9996  96.915760
# 9997  69.824421
# 9998  87.350048
# 9999  89.198699
#
# [10000 rows x 1 columns]

# %%
df_inference.set_index('output',inplace = True)
df_inference
# Out:
# Empty DataFrame
# Columns: []
# Index: [78.27996974613608, 58.33347162713689, 58.05158489868297, 57.71589798653031, 82.79843454833649, 65.42336403579316, 63.57502485736941, 55.523987223375016, 80.16525717829303, 38.5402912481581, 74.88712668040209, 70.08797642332776, 69.0583901877832, 79.95167977459325, 54.956563166027294, 88.01480096401949, 84.26729190234927, 80.53322409807508, 64.98894918407443, 74.23720401645015, 50.711593940894176, 87.79224589174733, 72.89236235883921, 75.67205484785943, 79.16214735936703, 67.84764481995566, 78.47914531927317, 53.81447309785889, 39.010559720813916, 67.93714662327518, 65.72485990726996, 84.58747619292242, 75.56797478557431, 89.40068386151316, 76.87326725113059, 61.804308597621365, 73.95378166895566, 83.4432627305054, 62.2690906370769, 57.248767443422, 84.46910380120073, 64.68244690237437, 77.9519389065448, 75.53064361792825, 52.88146704038287, 79.9744609220146, 78.82331979338726, 48.943337698497146, 55.28595750305212, 69.550238324221, 40.99846840566977, 82.82887041902507, 73.54188845214414, 78.75730143830407, 70.42071560296797, 61.51362016852398, 77.40908674920112, 61.530868812281334, 73.4369916837501, 68.14789103222455, 84.40529638070204, 81.64764991347008, 90.10799304752682, 66.23192216663574, 34.91737849123597, 84.17821340053322, 79.78730989894312, 48.88555372185554, 61.68374209533792, 79.21115884659204, 60.25981812284318, 89.93577985048542, 78.74696351847052, 67.67390293497465, 82.78224135126446, 71.9737233991857, 85.48226588258343, 51.3610742763326, 52.029308079883734, 62.6375845709101, 68.3794484350018, 69.69176012257753, 67.3170737325072, 61.665449709119144, 56.77519487768749, 78.44571301659053, 65.92905013853026, 42.5299401771659, 60.07978836556028, 78.49227449051894, 85.06231263541432, 58.08229912179037, 64.49092222699463, 75.97086351699568, 48.89679456273407, 70.56425776052883, 82.71240653398034, 59.83727859452454, 81.42405078059093, 61.22208802176576, ...]
#
# [10000 rows x 0 columns]

# %%
df_inference.to_csv('file.csv')
